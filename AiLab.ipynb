# %% [markdown]
# <a href="https://colab.research.google.com/github/Rizwan-1828/AI/blob/main/AiLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import plotly.express as px

# %%
from google.colab import files
for _ in range(2):
  uploaded = files.upload()

# %%
df = pd.read_csv(r"/content/Forbes Richest Atheletes (Forbes Richest Athletes 1990-2020).csv")
df
# Out:
#      S.NO               Name Nationality  Current Rank Previous Year Rank  \
# 0       1         Mike Tyson         USA             1                NaN
# 1       2     Buster Douglas         USA             2                NaN
# 2       3  Sugar Ray Leonard         USA             3                NaN
# 3       4       Ayrton Senna      Brazil             4                NaN
# 4       5        Alain Prost      France             5                NaN
# ..    ...                ...         ...           ...                ...
# 296   297      Stephen Curry         USA             6                  9
# 297   298       Kevin Durant         USA             7                 10
# 298   299        Tiger Woods         USA             8                 11
# 299   300       Kirk Cousins         USA             9               >100
# 300   301       Carson Wentz         USA            10               >100
#
#                  Sport  Year  earnings ($ million)
# ...

# %%
df.shape
# Out:
# (301, 8)

# %%
df.info
# Out:
# <bound method DataFrame.info of      S.NO               Name Nationality  Current Rank Previous Year Rank  \
# 0       1         Mike Tyson         USA             1                NaN
# 1       2     Buster Douglas         USA             2                NaN
# 2       3  Sugar Ray Leonard         USA             3                NaN
# 3       4       Ayrton Senna      Brazil             4                NaN
# 4       5        Alain Prost      France             5                NaN
# ..    ...                ...         ...           ...                ...
# 296   297      Stephen Curry         USA             6                  9
# 297   298       Kevin Durant         USA             7                 10
# 298   299        Tiger Woods         USA             8                 11
# 299   300       Kirk Cousins         USA             9               >100
# 300   301       Carson Wentz         USA            10               >100
#
# ...

# %%
df.head(5)
# Out:
#    S.NO               Name Nationality  Current Rank Previous Year Rank  \
# 0     1         Mike Tyson         USA             1                NaN
# 1     2     Buster Douglas         USA             2                NaN
# 2     3  Sugar Ray Leonard         USA             3                NaN
# 3     4       Ayrton Senna      Brazil             4                NaN
# 4     5        Alain Prost      France             5                NaN
#
#          Sport  Year  earnings ($ million)
# 0       boxing  1990                  28.6
# 1       boxing  1990                  26.0
# 2       boxing  1990                  13.0
# 3  auto racing  1990                  10.0
# 4  auto racing  1990                   9.0

# %%
df.tail(6)
# Out:
#      S.NO           Name Nationality  Current Rank Previous Year Rank  \
# 295   296   LeBron James         USA             5                  8
# 296   297  Stephen Curry         USA             6                  9
# 297   298   Kevin Durant         USA             7                 10
# 298   299    Tiger Woods         USA             8                 11
# 299   300   Kirk Cousins         USA             9               >100
# 300   301   Carson Wentz         USA            10               >100
#
#                  Sport  Year  earnings ($ million)
# 295         Basketball  2020                  88.2
# 296         Basketball  2020                  74.4
# 297         Basketball  2020                  63.9
# 298               Golf  2020                  62.3
# 299  American Football  2020                  60.5
# 300  American Football  2020                  59.1

# %%
df['Nationality'].value_counts()
# Out:
# USA                 206
# UK                   13
# Germany              13
# Switzerland          12
# Portugal             10
# Brazil                9
# Argentina             9
# Canada                6
# Italy                 4
# Finland               3
# France                3
# Philippines           3
# Russia                1
# Australia             1
# Dominican             1
# Austria               1
# Filipino              1
# Spain                 1
# Serbia                1
# Northern Ireland      1
# Ireland               1
# Mexico                1
# Name: Nationality, dtype: int64

# %%
df.groupby("Nationality").count()
# Out:
#                   S.NO  Name  Current Rank  Previous Year Rank  Sport  Year  \
# Nationality
# Argentina            9     9             9                   9      9     9
# Australia            1     1             1                   0      1     1
# Austria              1     1             1                   1      1     1
# Brazil               9     9             9                   8      9     9
# Canada               6     6             6                   6      6     6
# Dominican            1     1             1                   1      1     1
# Filipino             1     1             1                   1      1     1
# Finland              3     3             3                   3      3     3
# France               3     3             3                   2      3     3
# Germany             13    13            13                  12     13    13
# Ireland              1     1             1                   1      1     1
# ...

# %%
df.groupby("Nationality")["earnings ($ million)"].sum().plot(kind="bar")
plt.title("Total Earning as per Country")
# Out:
# Text(0.5, 1.0, 'Total Earning as per Country')

# %%
df.isnull().sum()
# Out:
# S.NO                     0
# Name                     0
# Nationality              0
# Current Rank             0
# Previous Year Rank      24
# Sport                    0
# Year                     0
# earnings ($ million)     0
# dtype: int64

# %%
df.groupby("Nationality")["S.NO"].count().sort_values(ascending=False).plot(kind='bar')
plt.title("Athelets from each country")
# Out:
# Text(0.5, 1.0, 'Athelets from each country')
